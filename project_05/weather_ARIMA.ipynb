# %%
import pandas as pd
import numpy as np
df = pd.read_csv('data.csv')

from sklearn.compose import ColumnTransformer

from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.graphics.tsaplots import plot_pacf, plot_acf

from datetime import datetime
from sklearn.linear_model import LinearRegression
import seaborn as sns 

from sklearn.model_selection import cross_val_score
from sklearn.metrics import mean_squared_error

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df.head()
# Out:
#     SOUID      DATE  TG  Q_TG
# 0  127488  18760101  22     0
# 1  127488  18760102  25     0
# 2  127488  18760103   3     0
# 3  127488  18760104 -58     0
# 4  127488  18760105 -98     0

# %%
del df['SOUID']
del df['Q_TG']

# %%
df['TG'].plot()              # check values, will need to fill in missing values

# %%
df.index[df['TG']<-800]
# Out:
# Int64Index([25316, 25317, 25318, 25319, 25320, 25321, 25322, 25323, 25324,
#             25325,
#             ...
#             25501, 25502, 25503, 25504, 25505, 25506, 25507, 25508, 25509,
#             25510],
#            dtype='int64', length=195)

# %%
df.set_index(pd.to_datetime(df['DATE'].astype(str)), inplace=True)     # convert to datetime format
del(df['DATE'])
df['TG'] = df['TG'] / 10
df.head()
# Out:
#              TG
# DATE
# 1876-01-01  2.2
# 1876-01-02  2.5
# 1876-01-03  0.3
# 1876-01-04 -5.8
# 1876-01-05 -9.8

# %%
#df.drop(df[(df.index.month==2) & (df.index.day==29)], axis = 0)
dfsubset = df[(df.index.month==2) & (df.index.day==29)]                      # drop feb 29 values

# %%
df=df.drop(dfsubset.index)

# %%
patch44 = df.loc['1944/04/25':'1944/11/05', 'TG']                    ## fix the missing values
patch46 = df.loc['1946/04/25':'1946/11/05', 'TG']

avg = (patch44.values + patch46.values) / 2                          # mean of previous and next year

df.loc['1945/04/25':'1945/11/05', 'TG'] = avg

# %%
df.loc['1944/01/01':'1944/12/31', 'TG']
# Out:
# DATE
# 1944-01-01    1.8
# 1944-01-02    6.8
# 1944-01-03    5.3
# 1944-01-04    0.4
# 1944-01-05   -1.9
#              ...
# 1944-12-27   -6.6
# 1944-12-28   -3.4
# 1944-12-29   -5.2
# 1944-12-30   -4.0
# 1944-12-31   -0.8
# Name: TG, Length: 365, dtype: float64

# %%
# add timestep values
df['timestep']=range(len(df.index))

# %%
df_train = df['1876-01':'1999-12'].copy()              # train-test split
df_test = df['2000-01':'2020-09'].copy()

# %%
plt.rcParams["figure.figsize"] = [20, 10]

# %%
df_train['TG'].plot()

# %%
sns_plot = sns.regplot(x = 'timestep', y = 'TG', data = df_train, scatter_kws={"color": "black"}, line_kws={"color": "red"})

# %%
df_train.head()
# Out:
#              TG  timestep
# DATE
# 1876-01-01  2.2         0
# 1876-01-02  2.5         1
# 1876-01-03  0.3         2
# 1876-01-04 -5.8         3
# 1876-01-05 -9.8         4

# %%
df_train['difference'] = df_train['TG'].diff(periods=1)             # Create difference column for removing trend

# %%
df_train['difference'].plot()

# %%
df_train['monthly mean'] = df_train.groupby(df_train.index.month)['difference'].transform('mean') # seasonality: create mean monthly difference column

# %%
monthlymeans = list(df_train.groupby(df_train.index.month)['difference'].mean()) # also save into a list

# %%
monthlymeans
# Out:
# [-0.007754358574030697,
#  0.08309331797235031,
#  0.14479708636836627,
#  0.14723118279569825,
#  0.17049947970863638,
#  0.06573924731182815,
#  0.03207596253902184,
#  -0.0910509885535903,
#  -0.1393413978494621,
#  -0.18717481789802254,
#  -0.12784946236559122,
#  -0.08459937565036431]

# %%
df_train['deseasonalized'] = df_train['difference'] - df_train['monthly mean']

# %%
df_train['deseasonalized']
# Out:
# DATE
# 1876-01-01         NaN
# 1876-01-02    0.307754
# 1876-01-03   -2.192246
# 1876-01-04   -6.092246
# 1876-01-05   -3.992246
#                 ...
# 1999-12-27   -1.015401
# 1999-12-28    0.284599
# 1999-12-29    0.284599
# 1999-12-30    0.684599
# 1999-12-31   -1.915401
# Name: deseasonalized, Length: 45260, dtype: float64

# %%
ypred=df_train['deseasonalized'].mean()   # baseline (mean) prediction after trend and seasonality is removed

# %%
ypred
# Out:
# 2.742012189677191e-17

# %%
df_train.head()
# Out:
#              TG  timestep  difference  monthly mean  deseasonalized
# DATE
# 1876-01-01  2.2         0         NaN     -0.007754             NaN
# 1876-01-02  2.5         1         0.3     -0.007754        0.307754
# 1876-01-03  0.3         2        -2.2     -0.007754       -2.192246
# 1876-01-04 -5.8         3        -6.1     -0.007754       -6.092246
# 1876-01-05 -9.8         4        -4.0     -0.007754       -3.992246

# %%
y_train = df_train['deseasonalized'][1:]       # dropping first NaN value

# %%
y_train
# Out:
# DATE
# 1876-01-02    0.307754
# 1876-01-03   -2.192246
# 1876-01-04   -6.092246
# 1876-01-05   -3.992246
# 1876-01-06    2.107754
#                 ...
# 1999-12-27   -1.015401
# 1999-12-28    0.284599
# 1999-12-29    0.284599
# 1999-12-30    0.684599
# 1999-12-31   -1.915401
# Name: deseasonalized, Length: 45259, dtype: float64

# %%
#df_train['y-2'] = df_train['deseasonalized'].shift(2)

# %%
df_train.head()
# Out:
#              TG  timestep  difference  monthly mean  deseasonalized
# DATE
# 1876-01-01  2.2         0         NaN     -0.007754             NaN
# 1876-01-02  2.5         1         0.3     -0.007754        0.307754
# 1876-01-03  0.3         2        -2.2     -0.007754       -2.192246
# 1876-01-04 -5.8         3        -6.1     -0.007754       -6.092246
# 1876-01-05 -9.8         4        -4.0     -0.007754       -3.992246

# %%
y_train = df_train['deseasonalized'][1:]       # dropping NaN values

# %%
x_train = df_train['timestep'][1:].to_frame()

# %%
x_train
# Out:
#             timestep
# DATE
# 1876-01-02         1
# 1876-01-03         2
# 1876-01-04         3
# 1876-01-05         4
# 1876-01-06         5
# ...              ...
# 1999-12-27     45255
# 1999-12-28     45256
# 1999-12-29     45257
# 1999-12-30     45258
# 1999-12-31     45259
#
# [45259 rows x 1 columns]

# %%
tr = ColumnTransformer([
    ('timesteps', 'passthrough', ['timestep']),
])

# %%
tr.fit(x_train)
x_train_trans = tr.transform(x_train)

# %%
x_train_trans
# Out:
# array([[    1],
#        [    2],
#        [    3],
#        ...,
#        [45257],
#        [45258],
#        [45259]])

# %%
x_test = df_test[['timestep']]

# %%
x_test_trans = tr.transform(x_test)

# %%
linreg = LinearRegression()

# %%
linreg.fit(x_train_trans, y_train)
# Out:
# LinearRegression()

# %%
cross_val_result = cross_val_score(linreg, x_train_trans, y_train)

# %%
cross_val_result
# Out:
# array([-2.10892157e-07, -9.26488612e-08, -1.22637918e-08, -1.43904637e-08,
#        -5.86057447e-09])

# %%
linreg.score(x_train_trans, y_train)
# Out:
# 1.2157770346021834e-09

# %%
df_test_predict = df_test.drop('TG',axis = 1)

# %%
df_test_predict
# Out:
#             timestep
# DATE
# 2000-01-01     45260
# 2000-01-02     45261
# 2000-01-03     45262
# 2000-01-04     45263
# 2000-01-05     45264
# ...              ...
# 2020-09-26     52828
# 2020-09-27     52829
# 2020-09-28     52830
# 2020-09-29     52831
# 2020-09-30     52832
#
# [7573 rows x 1 columns]

# %%
predictions = linreg.predict(df_test_predict)

# %%
predictions
# Out:
# array([0.00014494, 0.00014495, 0.00014495, ..., 0.00019343, 0.00019343,
#        0.00019344])

# %%
df_test['TGPRED']=predictions    # this will be the prediction column

# %%
df_test
# Out:
#               TG  timestep    TGPRED
# DATE
# 2000-01-01   1.4     45260  0.000145
# 2000-01-02   3.9     45261  0.000145
# 2000-01-03   5.9     45262  0.000145
# 2000-01-04   5.3     45263  0.000145
# 2000-01-05   3.0     45264  0.000145
# ...          ...       ...       ...
# 2020-09-26  10.4     52828  0.000193
# 2020-09-27   9.9     52829  0.000193
# 2020-09-28  13.9     52830  0.000193
# 2020-09-29  14.4     52831  0.000193
# 2020-09-30  13.9     52832  0.000193
#
# [7573 rows x 3 columns]

# %%
ypred = df_test[df_test['timestep']==45260]['TGPRED']

# %%
ypred + 2
# Out:
# DATE
# 2000-01-01    2.000145
# Name: TGPRED, dtype: float64

# %%
currmonth = df_test[df_test['timestep']==45260].index.month[0]        # let's predict the first step of the test dataframe
ypred = df_test[df_test['timestep']==45260]['TGPRED']
ypred = df_test[df_test['timestep']==45260]['TGPRED']
ypred_reconstruced = ypred + monthlymeans[currmonth-1]                # add back monthly mean
# De-diff using the last observed value from the train dataframe:
ypred_temp_reconstruced = df_train[df_train['timestep']==45259]['TG'][0] + ypred_reconstruced
df_test.loc[df_test['timestep']==45260,'TGPRED'] = ypred_temp_reconstruced

# %%
df_test.head()
# Out:
#              TG  timestep    TGPRED
# DATE
# 2000-01-01  1.4     45260 -0.207609
# 2000-01-02  3.9     45261  0.000145
# 2000-01-03  5.9     45262  0.000145
# 2000-01-04  5.3     45263  0.000145
# 2000-01-05  3.0     45264  0.000145

# %%
# Do the prediction for the test dataframe step by step:
for i in range(45261, 52833):
    ypred = df_test[df_test['timestep']==i]['TGPRED']
    currmonth = df_test[df_test['timestep']==i].index.month[0]
    ypred_reconstruced = ypred + monthlymeans[currmonth-1]
    ypred_temp_reconstruced = df_test[df_test['timestep']==i-1]['TGPRED'][0] + ypred_reconstruced
    df_test.loc[df_test['timestep']==i,'TGPRED'] = ypred_temp_reconstruced

# %%
df_test['TGPRED'].plot()

# %%
# del df_test['timestep']            # don't really need this anymore after prediction

# %%
df_test['2004-01':'2020-01'].plot()          # display baseline model for a few years

# %%
df_test
# Out:
#               TG  timestep     TGPRED
# DATE
# 2000-01-01   1.4     45260  -0.207609
# 2000-01-02   3.9     45261  -0.215219
# 2000-01-03   5.9     45262  -0.222828
# 2000-01-04   5.3     45263  -0.230438
# 2000-01-05   3.0     45264  -0.238047
# ...          ...       ...        ...
# 2020-09-26  10.4     52828  13.490587
# 2020-09-27   9.9     52829  13.351439
# 2020-09-28  13.9     52830  13.212291
# 2020-09-29  14.4     52831  13.073143
# 2020-09-30  13.9     52832  12.933995
#
# [7573 rows x 3 columns]

# %%
print(mean_squared_error(df_test['TG'], df_test['TGPRED']))
# Out:
# 15.072660351903531

# %%
# Autoregression component

# %%
plot_pacf(df_train['TG'][3:], lags = 10)
plt.show()

# %%
from statsmodels.tsa.arima.model import ARIMA

# %%
arima_model = ARIMA(endog=df_train['TG'], order=(1,2,1))
# Out:
# /home/boti/anaconda3/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:216: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# /home/boti/anaconda3/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:216: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# /home/boti/anaconda3/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:216: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'

# %%
result_arima = arima_model.fit()

# %%
print(result_arima.summary())
# Out:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                     TG   No. Observations:                45260
# Model:                 ARIMA(1, 2, 1)   Log Likelihood             -103893.342
# Date:                Fri, 30 Oct 2020   AIC                         207792.684
# Time:                        13:57:42   BIC                         207818.845
# Sample:                             0   HQIC                        207800.917
#                               - 45260
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.0176      0.004      4.018      0.000       0.009       0.026
# ma.L1         -1.0000      0.004   -261.647      0.000      -1.007      -0.992
# sigma2         5.7722      0.040    142.719      0.000       5.693       5.851
# ===================================================================================
# Ljung-Box (Q):                     2167.58   Jarque-Bera (JB):              2080.42
# Prob(Q):                              0.00   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.12   Skew:                            -0.15
# Prob(H) (two-sided):                  0.00   Kurtosis:                         4.01
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
plt.plot(result_arima.predict(start=45260, end=45360))
# Out:
# /home/boti/anaconda3/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:580: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   warnings.warn('No supported index is available.'

# %%
output = result_arima.forecast()
# Out:
# /home/boti/anaconda3/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:580: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   warnings.warn('No supported index is available.'

# %%
output
# Out:
# 45260   -0.235429
# dtype: float64

# %%
df_train['y-1'] = df_train['TG'].shift(1)
df_train['y-3'] = df_train['TG'].shift(3)

# %%
linreg_autoreg = LinearRegression()

# %%
df_train
# Out:
#              TG  timestep  difference  monthly mean  deseasonalized  y-1  y-3
# DATE
# 1876-01-01  2.2         0         NaN     -0.007754             NaN  NaN  NaN
# 1876-01-02  2.5         1         0.3     -0.007754        0.307754  2.2  NaN
# 1876-01-03  0.3         2        -2.2     -0.007754       -2.192246  2.5  NaN
# 1876-01-04 -5.8         3        -6.1     -0.007754       -6.092246  0.3  2.2
# 1876-01-05 -9.8         4        -4.0     -0.007754       -3.992246 -5.8  2.5
# ...         ...       ...         ...           ...             ...  ...  ...
# 1999-12-27  0.8     45255        -1.1     -0.084599       -1.015401  1.9  1.9
# 1999-12-28  1.0     45256         0.2     -0.084599        0.284599  0.8  4.2
# 1999-12-29  1.2     45257         0.2     -0.084599        0.284599  1.0  1.9
# 1999-12-30  1.8     45258         0.6     -0.084599        0.684599  1.2  0.8
# 1999-12-31 -0.2     45259        -2.0     -0.084599       -1.915401  1.8  1.0
#
# [45260 rows x 7 columns]

# %%
x_train_autoreg = df_train[['y-1', 'y-3']][4:]

# %%
y_train_autoreg = df_train[['TG']][4:]

# %%
x_train_autoreg
# Out:
#             y-1  y-3
# DATE
# 1876-01-05 -5.8  2.5
# 1876-01-06 -9.8  0.3
# 1876-01-07 -7.7 -5.8
# 1876-01-08 -6.6 -9.8
# 1876-01-09 -8.9 -7.7
# ...         ...  ...
# 1999-12-27  1.9  1.9
# 1999-12-28  0.8  4.2
# 1999-12-29  1.0  1.9
# 1999-12-30  1.2  0.8
# 1999-12-31  1.8  1.0
#
# [45256 rows x 2 columns]

# %%
y_train_autoreg
# Out:
#               TG
# DATE
# 1876-01-05  -9.8
# 1876-01-06  -7.7
# 1876-01-07  -6.6
# 1876-01-08  -8.9
# 1876-01-09 -12.7
# ...          ...
# 1999-12-27   0.8
# 1999-12-28   1.0
# 1999-12-29   1.2
# 1999-12-30   1.8
# 1999-12-31  -0.2
#
# [45256 rows x 1 columns]

# %%
linreg_autoreg.fit(x_train_autoreg, y_train_autoreg)
# Out:
# LinearRegression()

# %%
linreg_autoreg.score(x_train_autoreg, y_train_autoreg)
# Out:
# 0.9095678276887187

# %%
df_test
# Out:
#               TG  timestep     TGPRED
# DATE
# 2000-01-01   1.4     45260  -0.207609
# 2000-01-02   3.9     45261  -0.215219
# 2000-01-03   5.9     45262  -0.222828
# 2000-01-04   5.3     45263  -0.230438
# 2000-01-05   3.0     45264  -0.238047
# ...          ...       ...        ...
# 2020-09-26  10.4     52828  13.490587
# 2020-09-27   9.9     52829  13.351439
# 2020-09-28  13.9     52830  13.212291
# 2020-09-29  14.4     52831  13.073143
# 2020-09-30  13.9     52832  12.933995
#
# [7573 rows x 3 columns]

# %%
df_test['y-1'] = df_test['TGPRED'].shift(1)
df_test['y-3'] = df_test['TGPRED'].shift(3)

# %%
df_test
# Out:
#               TG  timestep     TGPRED        y-1        y-3
# DATE
# 2000-01-01   1.4     45260  -0.207609        NaN        NaN
# 2000-01-02   3.9     45261  -0.215219  -0.207609        NaN
# 2000-01-03   5.9     45262  -0.222828  -0.215219        NaN
# 2000-01-04   5.3     45263  -0.230438  -0.222828  -0.207609
# 2000-01-05   3.0     45264  -0.238047  -0.230438  -0.215219
# ...          ...       ...        ...        ...        ...
# 2020-09-26  10.4     52828  13.490587  13.629735  13.908031
# 2020-09-27   9.9     52829  13.351439  13.490587  13.768883
# 2020-09-28  13.9     52830  13.212291  13.351439  13.629735
# 2020-09-29  14.4     52831  13.073143  13.212291  13.490587
# 2020-09-30  13.9     52832  12.933995  13.073143  13.351439
#
# [7573 rows x 5 columns]

# %%
df_test = df_test[4:]

# %%
df_test_predict_autoreg = df_test.drop(['TG','timestep','TGPRED'],axis = 1)

# %%
predictions_autoreg = linreg_autoreg.predict(df_test_predict_autoreg)

# %%
df_test['TGPREDAUTOREG']=predictions_autoreg    # this will be the prediction column
# Out:
# <ipython-input-84-3e97fa2eff49>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['TGPREDAUTOREG']=predictions_autoreg    # this will be the prediction column

# %%
df_test
# Out:
#               TG  timestep     TGPRED        y-1        y-3  TGPREDAUTOREG
# DATE
# 2000-01-05   3.0     45264  -0.238047  -0.230438  -0.215219       0.158731
# 2000-01-06   2.1     45265  -0.245656  -0.238047  -0.222828       0.151435
# 2000-01-07   4.6     45266  -0.253266  -0.245656  -0.230438       0.144138
# 2000-01-08   4.4     45267  -0.260875  -0.253266  -0.238047       0.136842
# 2000-01-09   4.5     45268  -0.268485  -0.260875  -0.245656       0.129546
# ...          ...       ...        ...        ...        ...            ...
# 2020-09-26  10.4     52828  13.490587  13.629735  13.908031      13.464116
# 2020-09-27   9.9     52829  13.351439  13.490587  13.768883      13.330690
# 2020-09-28  13.9     52830  13.212291  13.351439  13.629735      13.197265
# 2020-09-29  14.4     52831  13.073143  13.212291  13.490587      13.063840
# 2020-09-30  13.9     52832  12.933995  13.073143  13.351439      12.930415
#
# [7569 rows x 6 columns]

# %%
print(mean_squared_error(df_test['TG'], df_test['TGPREDAUTOREG']))
# Out:
# 15.219918860205759
